# %%
import threading

# %%
sem=threading.BoundedSemaphore(5)

# %%
sem._value
# Out:
# 5

# %%
sem.acquire()
# Out:
# True

# %%
sem._value
# Out:
# 4

# %%
threading.enumerate

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
client.close()

# %%
pymongo.
