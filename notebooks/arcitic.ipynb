# %%
import arctic
from datetime import timedelta
from arctic import *

# %%
store=arctic.Arctic('localhost')
tickstore

# %%
relativedelta

# %%
print(store)
# Out:
# <arctic.store._pandas_ndarray_store.PandasDataFrameStore object at 0x7fafe4c71438>

# %%
library=store.initialize_library('pandas_test')

# %%
print(library)
# Out:
# None
