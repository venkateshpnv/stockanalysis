# %%
import pandas
import pandas as pd
import pandas_datareader as pdr
import pandas_datareader.data as data
from datetime import date, timedelta, datetime as dt
import h5py
from dateutil.relativedelta import relativedelta

# %%
relativedelta
# Out:
# dateutil.relativedelta.relativedelta

# %%
f=pd.HDFStore('/tmp/test.h5', mode='a', complevel=9, complib='bzip2')

# %%
f.append

# %%
end=dt.now().date()
end=str(end - timedelta(days=5))
since="1984-09-01"
since_start = dt.strptime(since, "%Y-%m-%d").date()

# %%
data.RobinhoodHistoricalReader
# Out:
# pandas_datareader.robinhood.RobinhoodHistoricalReader

# %%
end
# Out:
# '2019-10-28'

# %%
since_start
# Out:
# datetime.date(1984, 9, 1)

# %%
df= pdr.DataReader('AAPL','yahoo',since_start,end, retry_count=3)

# %%
df.to_hdf

# %%
import h5py
f=h5py.File('/tmp/US_price_data.hd5','r+')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-0605fd433bc9> in <module>
#       1 import h5py
# ----> 2 f=h5py.File('/tmp/US_price_data.hd5','r+')
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
# ...

# %%
df.index.get_loc

# %%
df.loc['1984-09-04']['Adj Close']
# Out:
# 0.37340840697288513

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8850 entries, 1984-09-04 to 2019-10-11
# Data columns (total 6 columns):
# High         8850 non-null float64
# Low          8850 non-null float64
# Open         8850 non-null float64
# Close        8850 non-null float64
# Volume       8850 non-null float64
# Adj Close    8850 non-null float64
# dtypes: float64(6)
# memory usage: 484.0 KB

# %%
df.index()

# %%
store = pandas.HDFStore('/tmp/US_Stocks.h5')

# %%
#df.to_hdf('/tmp/US_Stocks.h5', key='AAPL', format='table') #table=True, mode='a')
store.put('AAPL', df, format='table', append=True, data_columns=True)

# %%
print(store['AAPL'])
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 1984-09-04    0.477679    0.464286    0.473214    0.468750  29960000.0
# 1984-09-05    0.475446    0.464286    0.468750    0.468750  25939200.0
# 1984-09-06    0.479911    0.468750    0.468750    0.473214  32743200.0
# 1984-09-07    0.479911    0.468750    0.473214    0.473214  20815200.0
# 1984-09-10    0.475446    0.462054    0.473214    0.470982  16156000.0
# 1984-09-11    0.488839    0.475446    0.475446    0.479911  38096800.0
# 1984-09-12    0.482143    0.466518    0.479911    0.466518  33280800.0
# 1984-09-13    0.493304    0.491071    0.491071    0.491071  51833600.0
# 1984-09-14    0.508929    0.493304    0.493304    0.497768  61717600.0
# 1984-09-17    0.517857    0.511161    0.511161    0.511161  48188000.0
# 1984-09-18    0.515625    0.493304    0.511161    0.493304  24326400.0
# 1984-09-19    0.497768    0.482143    0.493304    0.482143  26572000.0
# ...

# %%
end=dt.now().date()
start=str(end - timedelta(days=4))
end=str(end)
print(end)
print(start)
# Out:
# 2019-10-17
# 2019-10-13

# %%
df= pdr.DataReader('AAPL','yahoo',start,end, retry_count=3)

# %%
df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2019-10-14  238.130005  234.669998  234.899994  235.869995  24106900
# 2019-10-15  237.649994  234.880005  236.389999  235.320007  21840000
# 2019-10-16  235.240005  233.199997  233.369995  234.369995  18475800
# 2019-10-17  236.149994  233.552307  235.089996  233.860001   8643151
#
#              Adj Close
# Date
# 2019-10-14  235.869995
# 2019-10-15  235.320007
# 2019-10-16  234.369995
# 2019-10-17  233.860001

# %%
store.info()
# Out:
# "<class 'pandas.io.pytables.HDFStore'>\nFile path: /tmp/US_Stocks.h5\n/AAPL            frame_table  (typ->appendable,nrows->8850,ncols->6,indexers->[index],dc->[High,Low,Open,Close,Volume,Adj Close])"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4 entries, 2019-10-14 to 2019-10-17
# Data columns (total 6 columns):
# High         4 non-null float64
# Low          4 non-null float64
# Open         4 non-null float64
# Close        4 non-null float64
# Volume       4 non-null int64
# Adj Close    4 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 224.0 bytes

# %%
df=df.astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4 entries, 2019-10-14 to 2019-10-17
# Data columns (total 6 columns):
# High         4 non-null float64
# Low          4 non-null float64
# Open         4 non-null float64
# Close        4 non-null float64
# Volume       4 non-null float64
# Adj Close    4 non-null float64
# dtypes: float64(6)
# memory usage: 224.0 bytes

# %%
#df.to_hdf('/tmp/US_Stocks.h5', 'AAPL', table=True, mode='a')
#df.to_hdf('/tmp/US_Stocks.h5', key='AAPL', format='table', append=True, mode='a')

store.append('AAPL', df, format='table', append=True, data_columns=True)

# %%
print(store['AAPL'])
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 1984-09-04    0.477679    0.464286    0.473214    0.468750  29960000.0
# 1984-09-05    0.475446    0.464286    0.468750    0.468750  25939200.0
# 1984-09-06    0.479911    0.468750    0.468750    0.473214  32743200.0
# 1984-09-07    0.479911    0.468750    0.473214    0.473214  20815200.0
# 1984-09-10    0.475446    0.462054    0.473214    0.470982  16156000.0
# 1984-09-11    0.488839    0.475446    0.475446    0.479911  38096800.0
# 1984-09-12    0.482143    0.466518    0.479911    0.466518  33280800.0
# 1984-09-13    0.493304    0.491071    0.491071    0.491071  51833600.0
# 1984-09-14    0.508929    0.493304    0.493304    0.497768  61717600.0
# 1984-09-17    0.517857    0.511161    0.511161    0.511161  48188000.0
# 1984-09-18    0.515625    0.493304    0.511161    0.493304  24326400.0
# 1984-09-19    0.497768    0.482143    0.493304    0.482143  26572000.0
# ...

# %%
#store=pandas.HDFStore('/tmp/US_Stocks.h5')

# %%
#store.put('AAPL', df, format='t', data_columns=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/tables/path.py:155: NaturalNameWarning: object name is not a valid Python identifier: 'Adj Close'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# /usr/local/lib/python3.6/dist-packages/tables/attributeset.py:464: NaturalNameWarning: object name is not a valid Python identifier: 'Adj Close_kind'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# ...
