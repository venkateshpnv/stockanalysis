# %%
import pymongo

# %%
def open_db(db_name):                                       
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    db = client[db_name]
    return db

# %%
db = open_db('Stocks')

#docs = db.US_Stocks.find({})
docs = db.US_Stocks.find({"fig.EPS_History": {"$exists": True}})
#docs = db.US_Stocks.find({"bscs.symbol":"AAPL"})

for doc in docs:
    #print(doc['bscs']['symbol'])
    keys = doc['fig']['EPS_History'].keys()
    #print(len(keys))

    for k in keys:
        if doc['fig']['EPS_History'][k]['eps'] == :
            print(doc['bscs']['symbol'])
            print(doc['fig']['EPS_History'][k]['eps'])
    #break
# Out:
# AMS
# 0.34
# NOG
# 0.34
# AIR
# 0.34
# ABB
# 0.34
# ABB
# 0.34
# ABB
# 0.34
# ABT
# 0.34
# ACCO
# 0.34
# ATGE
# 0.34
# AFL
# 0.34
# AFL
# 0.34
# AGCO
# 0.34
# AGCO
# 0.34
# A
# 0.34
# AEM
# 0.34
# AEM
# 0.34
# AYR
# 0.34
# AYR
# 0.34
# AGN
# 0.34
# AGN
# 0.34
# AEE
# 0.34
# AXL
# 0.34
# AXL
# 0.34
# AXL
# 0.34
# ACC
# 0.34
# ACC
# 0.34
# AEO
# 0.34
# AEO
# 0.34
# AWR
# 0.34
# AMT
# 0.34
# AMRX
# 0.34
# APC
# 0.34
# AR
# 0.34
# ARMK
# 0.34
# MT
# 0.34
# ARNC
# 0.34
# ARES
# 0.34
# ARES
# 0.34
# ARES
# 0.34
# AWI
# 0.34
# ARW
# 0.34
# AJG
# 0.34
# ASH
# 0.34
# ASB
# 0.34
# ASB
# 0.34
# HOME
# 0.34
# T
# 0.34
# T
# 0.34
# ATO
# 0.34
# AN
# 0.34
# AN
# 0.34
# AVP
# 0.34
# AVP
# 0.34
# AVP
# 0.34
# AVP
# 0.34
# AVX
# 0.34
# AXTA
# 0.34
# AXTA
# 0.34
# AZZ
# 0.34
# AZZ
# 0.34
# BGS
# 0.34
# BGS
# 0.34
# BGS
# 0.34
# BMI
# 0.34
# BXS
# 0.34
# B
# 0.34
# B
# 0.34
# GOLD
# 0.34
# BDC
# 0.34
# BHE
# 0.34
# BHE
# 0.34
# BHE
# 0.34
# BHE
# 0.34
# BBY
# 0.34
# BBY
# 0.34
# BSX
# 0.34
# BSX
# ...
